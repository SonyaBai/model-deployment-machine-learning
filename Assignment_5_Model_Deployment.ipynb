# %% [markdown]
# # Assignment 5: ML Model Deployment
#
# ## DTSC-680: Applied Machine Learning
#
# ## Name:

# %% [markdown]
# ### Overview
#
# In this assignment, you will locally deploy a machine learning model using Flask.

# %%
# common imports
import numpy as np
import pandas as pd

# %% [markdown]
# ### Model Development
#
# Run the following code to build and train a model on the titanic data.

# %%
# CODE PROVIDED

# Import the Titanic data.
df = pd.read_csv('Data/titanic.csv')

# Prepare the data for ML model training.
df = df[['Survived', 'Age', 'Sex', 'Pclass']]
df = pd.get_dummies(df, columns=['Sex', 'Pclass'])
df.dropna(inplace=True)

# Separate the data into features and responses
x = df.drop('Survived', axis=1)
y = df['Survived']

# Build and train a Logistic Regression model on the data
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(random_state=0)
model.fit(x, y)
# Out:
# LogisticRegression(random_state=0)

# %% [markdown]
# Pickle the model, saving it to a file called `titanic.pkl`.

# %%
import pickle

pickle.dump(model, open('titanic.pkl', 'wb'))

# %% [markdown]
# Deploy the model locally by making the following changes to the provided files in the deployment folder:
# - In the `application.py` file:
#     - Use the defined variables to create the DataFrame from the user's data.
#     - Load the model from the pickle file using joblib (see `application.py` file from in-class example)
#     - Use the model the predict on the user's data
# - In the `about.html` file, fill in personal information for the 'About' page.
# - In the `predict.html` file, edit the prediction message to say "The model prediction states that this person has a ______% chance of surviving."
